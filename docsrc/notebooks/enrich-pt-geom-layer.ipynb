# %% [markdown]
# # Enrich Using Point Geometries

# %% [markdown]
# Starting off, we import a few required Python resources. While there are quite a few in there, the import of note is `from arcgis.geoenrichment import Country, get_countries`. We are going to use this object and method to discover and perform our analysis.

# %%
import os
from pathlib import Path

from arcgis.features import GeoAccessor
from arcgis.geoenrichment import Country
from arcgis.geometry import Geometry
from arcgis.gis import GIS
from dotenv import load_dotenv, find_dotenv
import pandas as pd

load_dotenv(find_dotenv())
# Out:
# True

# %% [markdown]
# Now, we are going to need a connection to ArcGIS Online to demonstrate the abiliy to use ArcGIS Online for geoenrichment. This is accomplished by instantiating a `GIS` object instance with valid credentials read from environment variables.

# %%
gis_agol = GIS(
    url=os.getenv('ESRI_GIS_URL'), 
    username=os.getenv('ESRI_GIS_USERNAME'),
    password=os.getenv('ESRI_GIS_PASSWORD')
)

gis_agol
# Out:
# GIS @ https://baqa.mapsqa.arcgis.com version:9.4

# %% [markdown]
# Next, we need some test data to work with. We are pulling business locations from an ArcGIS Online layer.

# %%
pt_itm_id = '581de875ae96477298f7b5ac598b1dec'
pt_lyr = GIS().content.get(pt_itm_id).layers[0]
pt_df = pt_lyr.query().sdf.drop(columns='OBJECTID')
pt_df.spatial.set_geometry('SHAPE')

pt_df.info()
pt_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LOCNUM  251 non-null    object
#  1   SHAPE   251 non-null    geometry
# dtypes: geometry(1), object(1)
# memory usage: 4.0+ KB
#       LOCNUM                                              SHAPE
# 0  177692910  {"x": -122.63332499999997, "y": 45.41751900000...
# 1  207178880  {"x": -122.578461, "y": 45.49077900000012, "sp...
# 2  213604069  {"x": -122.68257749999998, "y": 45.52993800000...
# 3  214402802  {"x": -122.28194789999999, "y": 45.40177785000...
# 4  215047911  {"x": -122.73786899999999, "y": 45.41748299999...

# %% [markdown]
# To enrich, we start by creating a `Country` object instance. As part of the constructor, we need to tell the object what Business Analyst source to use in the `gis` parameter. In this case, we are telling the object to use a local instance of ArcGIS Pro with Business Analyst and the United States data pack.

# %%
usa_agol = Country('usa', gis=gis_agol)

usa_agol
# Out:
# <Country - United States (GIS @ https://baqa.mapsqa.arcgis.com version:9.4)>

# %% [markdown]
# ## Select Variables
#
# Next, we need to get some enrich variables to use. We can discover what is available using the `enrich_variables` property of the country object to retrieve a Pandas Data Frame of variables available for the country.

# %%
ev = usa_agol.enrich_variables

ev
# Out:
#              name                                              alias  \
# 0         AGE0_CY                             2021 Population Age <1
# 1         AGE1_CY                              2021 Population Age 1
# 2         AGE2_CY                              2021 Population Age 2
# 3         AGE3_CY                              2021 Population Age 3
# 4         AGE4_CY                              2021 Population Age 4
# ...           ...                                                ...
# 19148  MOEMEDYRMV  2019 Median Year Householder Moved In MOE (ACS...
# 19149  RELMEDYRMV  2019 Median Year Householder Moved In REL (ACS...
# 19150    ACSOWNER                   2019 Owner Households (ACS 5-Yr)
# 19151    MOEOWNER               2019 Owner Households MOE (ACS 5-Yr)
# 19152    RELOWNER               2019 Owner Households REL (ACS 5-Yr)
#
#        data_collection              enrich_name         enrich_field_name  \
# 0      1yearincrements  1yearincrements.AGE0_CY  F1yearincrements_AGE0_CY
# 1      1yearincrements  1yearincrements.AGE1_CY  F1yearincrements_AGE1_CY
# 2      1yearincrements  1yearincrements.AGE2_CY  F1yearincrements_AGE2_CY
# 3      1yearincrements  1yearincrements.AGE3_CY  F1yearincrements_AGE3_CY
# 4      1yearincrements  1yearincrements.AGE4_CY  F1yearincrements_AGE4_CY
# ...                ...                      ...                       ...
# 19148      yearmovedin   yearmovedin.MOEMEDYRMV    yearmovedin_MOEMEDYRMV
# 19149      yearmovedin   yearmovedin.RELMEDYRMV    yearmovedin_RELMEDYRMV
# 19150      yearmovedin     yearmovedin.ACSOWNER      yearmovedin_ACSOWNER
# 19151      yearmovedin     yearmovedin.MOEOWNER      yearmovedin_MOEOWNER
# 19152      yearmovedin     yearmovedin.RELOWNER      yearmovedin_RELOWNER
#
#                                              description    vintage  units
# 0                    2021 Total Population Age <1 (Esri)       2021  count
# 1                     2021 Total Population Age 1 (Esri)       2021  count
# 2                     2021 Total Population Age 2 (Esri)       2021  count
# 3                     2021 Total Population Age 3 (Esri)       2021  count
# 4                     2021 Total Population Age 4 (Esri)       2021  count
# ...                                                  ...        ...    ...
# 19148  2019 Median Year Householder Moved into Unit M...  2015-2019  count
# 19149  2019 Median Year Householder Moved into Unit R...  2015-2019  count
# 19150                   2019 Owner Households (ACS 5-Yr)  2015-2019  count
# 19151               2019 Owner Households MOE (ACS 5-Yr)  2015-2019  count
# 19152               2019 Owner Households REL (ACS 5-Yr)  2015-2019  count
#
# [19153 rows x 8 columns]

# %% [markdown]
# Tens of thousands of variables is just a few too many to deal with, so we can parse this down a bit using some Pandas Data Frame filtering to get just key United States variables for the current year.

# %%
kv = ev[
    (ev.data_collection.str.lower().str.contains('key'))
    & (ev.name.str.lower().str.endswith('cy'))
].reset_index(drop=True)

kv
# Out:
#           name                              alias data_collection  \
# 0    TOTPOP_CY              2021 Total Population      KeyUSFacts
# 1     GQPOP_CY     2021 Group Quarters Population      KeyUSFacts
# 2   DIVINDX_CY               2021 Diversity Index      KeyUSFacts
# 3     TOTHH_CY              2021 Total Households      KeyUSFacts
# 4   AVGHHSZ_CY        2021 Average Household Size      KeyUSFacts
# 5   MEDHINC_CY       2021 Median Household Income      KeyUSFacts
# 6   AVGHINC_CY      2021 Average Household Income      KeyUSFacts
# 7       PCI_CY             2021 Per Capita Income      KeyUSFacts
# 8     TOTHU_CY           2021 Total Housing Units      KeyUSFacts
# 9     OWNER_CY            2021 Owner Occupied HUs      KeyUSFacts
# 10   RENTER_CY           2021 Renter Occupied HUs      KeyUSFacts
# 11   VACANT_CY          2021 Vacant Housing Units      KeyUSFacts
# 12   MEDVAL_CY             2021 Median Home Value      KeyUSFacts
# 13   AVGVAL_CY            2021 Average Home Value      KeyUSFacts
# 14  POPGRW10CY  2010-2021 Growth Rate: Population      KeyUSFacts
# 15   HHGRW10CY  2010-2021 Growth Rate: Households      KeyUSFacts
# 16  FAMGRW10CY    2010-2021 Growth Rate: Families      KeyUSFacts
# 17     DPOP_CY      2021 Total Daytime Population      KeyUSFacts
# 18  DPOPWRK_CY          2021 Daytime Pop: Workers      KeyUSFacts
# 19  DPOPRES_CY        2021 Daytime Pop: Residents      KeyUSFacts
#
#               enrich_name      enrich_field_name  \
# 0    KeyUSFacts.TOTPOP_CY   KeyUSFacts_TOTPOP_CY
# 1     KeyUSFacts.GQPOP_CY    KeyUSFacts_GQPOP_CY
# 2   KeyUSFacts.DIVINDX_CY  KeyUSFacts_DIVINDX_CY
# 3     KeyUSFacts.TOTHH_CY    KeyUSFacts_TOTHH_CY
# 4   KeyUSFacts.AVGHHSZ_CY  KeyUSFacts_AVGHHSZ_CY
# 5   KeyUSFacts.MEDHINC_CY  KeyUSFacts_MEDHINC_CY
# 6   KeyUSFacts.AVGHINC_CY  KeyUSFacts_AVGHINC_CY
# 7       KeyUSFacts.PCI_CY      KeyUSFacts_PCI_CY
# 8     KeyUSFacts.TOTHU_CY    KeyUSFacts_TOTHU_CY
# 9     KeyUSFacts.OWNER_CY    KeyUSFacts_OWNER_CY
# 10   KeyUSFacts.RENTER_CY   KeyUSFacts_RENTER_CY
# 11   KeyUSFacts.VACANT_CY   KeyUSFacts_VACANT_CY
# 12   KeyUSFacts.MEDVAL_CY   KeyUSFacts_MEDVAL_CY
# 13   KeyUSFacts.AVGVAL_CY   KeyUSFacts_AVGVAL_CY
# 14  KeyUSFacts.POPGRW10CY  KeyUSFacts_POPGRW10CY
# 15   KeyUSFacts.HHGRW10CY   KeyUSFacts_HHGRW10CY
# 16  KeyUSFacts.FAMGRW10CY  KeyUSFacts_FAMGRW10CY
# 17     KeyUSFacts.DPOP_CY     KeyUSFacts_DPOP_CY
# 18  KeyUSFacts.DPOPWRK_CY  KeyUSFacts_DPOPWRK_CY
# 19  KeyUSFacts.DPOPRES_CY  KeyUSFacts_DPOPRES_CY
#
#                                           description vintage     units
# 0                        2021 Total Population (Esri)    2021     count
# 1               2021 Group Quarters Population (Esri)    2021     count
# 2                         2021 Diversity Index (Esri)    2021     count
# 3                        2021 Total Households (Esri)    2021     count
# 4                  2021 Average Household Size (Esri)    2021     count
# 5                 2021 Median Household Income (Esri)    2021  currency
# 6                2021 Average Household Income (Esri)    2021  currency
# 7                       2021 Per Capita Income (Esri)    2021  currency
# 8                     2021 Total Housing Units (Esri)    2021     count
# 9            2021 Owner Occupied Housing Units (Esri)    2021     count
# 10          2021 Renter Occupied Housing Units (Esri)    2021     count
# 11                   2021 Vacant Housing Units (Esri)    2021     count
# 12                      2021 Median Home Value (Esri)    2021  currency
# 13                     2021 Average Home Value (Esri)    2021  currency
# 14  2010-2021 Population: Compound Annual Growth R...    2021       pct
# 15  2010-2021 Households: Compound Annual Growth R...    2021       pct
# 16  2010-2021 Families: Compound Annual Growth Rat...    2021       pct
# 17               2021 Total Daytime Population (Esri)    2021     count
# 18            2021 Daytime Population: Workers (Esri)    2021     count
# 19          2021 Daytime Population: Residents (Esri)    2021     count

# %% [markdown]
# ## Enrich with Defaults
#
# Finally, we can enrich using the points and variables collected above. Please notice, we are not specifying the area around the input points, so the proximity defaults are being used - a straight line distance of one kilometer around the points. This circular area is then used to apportion data to the locations specified by the point geometries.

# %%
pt_df.head()
# Out:
#       LOCNUM                                              SHAPE
# 0  177692910  {"x": -122.63332499999997, "y": 45.41751900000...
# 1  207178880  {"x": -122.578461, "y": 45.49077900000012, "sp...
# 2  213604069  {"x": -122.68257749999998, "y": 45.52993800000...
# 3  214402802  {"x": -122.28194789999999, "y": 45.40177785000...
# 4  215047911  {"x": -122.73786899999999, "y": 45.41748299999...

# %%
pt1_enrich_df = usa_agol.enrich(
    geographies=pt_df,
    enrich_variables=kv
)

pt1_enrich_df.info()
pt1_enrich_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   locnum                             251 non-null    object
#  1   source_country                     251 non-null    object
#  2   area_type                          251 non-null    object
#  3   buffer_units                       251 non-null    object
#  4   buffer_units_alias                 251 non-null    object
#  5   buffer_radii                       251 non-null    int64
#  6   aggregation_method                 251 non-null    object
#  7   population_to_polygon_size_rating  251 non-null    float64
#  8   apportionment_confidence           251 non-null    float64
#  9   has_data                           251 non-null    int64
#  10  totpop_cy                          251 non-null    int64
#  11  gqpop_cy                           251 non-null    int64
#  12  divindx_cy                         251 non-null    float64
#  13  tothh_cy                           251 non-null    int64
#  14  avghhsz_cy                         251 non-null    float64
#  15  medhinc_cy                         251 non-null    int64
#  16  avghinc_cy                         251 non-null    int64
#  17  pci_cy                             251 non-null    int64
#  18  tothu_cy                           251 non-null    int64
#  19  owner_cy                           251 non-null    int64
#  20  renter_cy                          251 non-null    int64
#  21  vacant_cy                          251 non-null    int64
#  22  medval_cy                          251 non-null    int64
#  23  avgval_cy                          251 non-null    int64
#  24  popgrw10_cy                        251 non-null    float64
#  25  hhgrw10_cy                         251 non-null    float64
#  26  famgrw10_cy                        251 non-null    float64
#  27  dpop_cy                            251 non-null    int64
#  28  dpopwrk_cy                         251 non-null    int64
#  29  dpopres_cy                         251 non-null    int64
#  30  SHAPE                              251 non-null    geometry
# dtypes: float64(7), geometry(1), int64(17), object(6)
# memory usage: 60.9+ KB
#       locnum source_country   area_type buffer_units buffer_units_alias  \
# 0  177692910             US  RingBuffer    esriMiles              Miles
# 1  207178880             US  RingBuffer    esriMiles              Miles
# 2  213604069             US  RingBuffer    esriMiles              Miles
# 3  214402802             US  RingBuffer    esriMiles              Miles
# 4  215047911             US  RingBuffer    esriMiles              Miles
#
#    buffer_radii                                 aggregation_method  \
# 0             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 1             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 2             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 3             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 4             1  BlockApportionment:US.BlockGroups;PointsLayer:...
#
#    population_to_polygon_size_rating  apportionment_confidence  has_data  ...  \
# 0                              2.191                     2.576         1  ...
# 1                              2.191                     2.576         1  ...
# 2                              2.191                     2.576         1  ...
# 3                              2.191                     2.576         1  ...
# 4                              2.191                     2.576         1  ...
#
#    vacant_cy  medval_cy  avgval_cy  popgrw10_cy  hhgrw10_cy  famgrw10_cy  \
# 0        348     390413     429594         0.43        0.41         0.19
# 1        420     394983     441629         0.81        0.67         0.61
# 2       3773     628835     706736         2.86        2.81         3.17
# 3         94     376746     403178         2.64        2.52         2.44
# 4        158     575127     605756         0.41        0.47         0.20
#
#    dpop_cy  dpopwrk_cy  dpopres_cy  \
# 0    11715        4849        6866
# 1    20885        8823       12062
# 2    91264       75188       16076
# 3     5727        2799        2928
# 4    22915       18367        4548
#
#                                                SHAPE
# 0  {"x": -122.63332499999997, "y": 45.41751900000...
# 1  {"x": -122.578461, "y": 45.49077900000012, "sp...
# 2  {"x": -122.68257749999998, "y": 45.52993800000...
# 3  {"x": -122.28194789999999, "y": 45.40177785000...
# 4  {"x": -122.73786899999999, "y": 45.41748299999...
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Specify Proximity Value
#
# If wanting to use a value different from the default (highly recommended) of one kilometer, this can easily be specified using the `proximity_value` parameter.

# %%
pt2_enrich_df = usa_agol.enrich(
    geographies=pt_df,
    enrich_variables=kv,
    proximity_value=3
)

pt2_enrich_df.info()
pt2_enrich_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   locnum                             251 non-null    object
#  1   source_country                     251 non-null    object
#  2   area_type                          251 non-null    object
#  3   buffer_units                       251 non-null    object
#  4   buffer_units_alias                 251 non-null    object
#  5   buffer_radii                       251 non-null    int64
#  6   aggregation_method                 251 non-null    object
#  7   population_to_polygon_size_rating  251 non-null    float64
#  8   apportionment_confidence           251 non-null    float64
#  9   has_data                           251 non-null    int64
#  10  totpop_cy                          251 non-null    int64
#  11  gqpop_cy                           251 non-null    int64
#  12  divindx_cy                         251 non-null    float64
#  13  tothh_cy                           251 non-null    int64
#  14  avghhsz_cy                         251 non-null    float64
#  15  medhinc_cy                         251 non-null    int64
#  16  avghinc_cy                         251 non-null    int64
#  17  pci_cy                             251 non-null    int64
#  18  tothu_cy                           251 non-null    int64
#  19  owner_cy                           251 non-null    int64
#  20  renter_cy                          251 non-null    int64
#  21  vacant_cy                          251 non-null    int64
#  22  medval_cy                          251 non-null    int64
#  23  avgval_cy                          251 non-null    int64
#  24  popgrw10_cy                        251 non-null    float64
#  25  hhgrw10_cy                         251 non-null    float64
#  26  famgrw10_cy                        251 non-null    float64
#  27  dpop_cy                            251 non-null    int64
#  28  dpopwrk_cy                         251 non-null    int64
#  29  dpopres_cy                         251 non-null    int64
#  30  SHAPE                              251 non-null    geometry
# dtypes: float64(7), geometry(1), int64(17), object(6)
# memory usage: 60.9+ KB
#       locnum source_country   area_type buffer_units buffer_units_alias  \
# 0  177692910             US  RingBuffer    esriMiles              Miles
# 1  207178880             US  RingBuffer    esriMiles              Miles
# 2  213604069             US  RingBuffer    esriMiles              Miles
# 3  214402802             US  RingBuffer    esriMiles              Miles
# 4  215047911             US  RingBuffer    esriMiles              Miles
#
#    buffer_radii                                 aggregation_method  \
# 0             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 1             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 2             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 3             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 4             1  BlockApportionment:US.BlockGroups;PointsLayer:...
#
#    population_to_polygon_size_rating  apportionment_confidence  has_data  ...  \
# 0                              2.191                     2.576         1  ...
# 1                              2.191                     2.576         1  ...
# 2                              2.191                     2.576         1  ...
# 3                              2.191                     2.576         1  ...
# 4                              2.191                     2.576         1  ...
#
#    vacant_cy  medval_cy  avgval_cy  popgrw10_cy  hhgrw10_cy  famgrw10_cy  \
# 0        348     390413     429594         0.43        0.41         0.19
# 1        420     394983     441629         0.81        0.67         0.61
# 2       3773     628835     706736         2.86        2.81         3.17
# 3         94     376746     403178         2.64        2.52         2.44
# 4        158     575127     605756         0.41        0.47         0.20
#
#    dpop_cy  dpopwrk_cy  dpopres_cy  \
# 0    11715        4849        6866
# 1    20885        8823       12062
# 2    91264       75188       16076
# 3     5727        2799        2928
# 4    22915       18367        4548
#
#                                                SHAPE
# 0  {"x": -122.63332499999997, "y": 45.41751900000...
# 1  {"x": -122.578461, "y": 45.49077900000012, "sp...
# 2  {"x": -122.68257749999998, "y": 45.52993800000...
# 3  {"x": -122.28194789999999, "y": 45.40177785000...
# 4  {"x": -122.73786899999999, "y": 45.41748299999...
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Specify Proximity Value and Metric
#
# If desiring to use a different measure of distance, such as miles, this can be specified as well using the `proximity_metric` parameter.

# %%
pt3_enrich_df = usa_agol.enrich(
    geographies=pt_df,
    enrich_variables=kv,
    proximity_value=3,
    proximity_metric='miles'
)

pt3_enrich_df.info()
pt3_enrich_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   locnum                             251 non-null    object
#  1   source_country                     251 non-null    object
#  2   area_type                          251 non-null    object
#  3   buffer_units                       251 non-null    object
#  4   buffer_units_alias                 251 non-null    object
#  5   buffer_radii                       251 non-null    int64
#  6   aggregation_method                 251 non-null    object
#  7   population_to_polygon_size_rating  251 non-null    float64
#  8   apportionment_confidence           251 non-null    float64
#  9   has_data                           251 non-null    int64
#  10  totpop_cy                          251 non-null    int64
#  11  gqpop_cy                           251 non-null    int64
#  12  divindx_cy                         251 non-null    float64
#  13  tothh_cy                           251 non-null    int64
#  14  avghhsz_cy                         251 non-null    float64
#  15  medhinc_cy                         251 non-null    int64
#  16  avghinc_cy                         251 non-null    int64
#  17  pci_cy                             251 non-null    int64
#  18  tothu_cy                           251 non-null    int64
#  19  owner_cy                           251 non-null    int64
#  20  renter_cy                          251 non-null    int64
#  21  vacant_cy                          251 non-null    int64
#  22  medval_cy                          251 non-null    int64
#  23  avgval_cy                          251 non-null    int64
#  24  popgrw10_cy                        251 non-null    float64
#  25  hhgrw10_cy                         251 non-null    float64
#  26  famgrw10_cy                        251 non-null    float64
#  27  dpop_cy                            251 non-null    int64
#  28  dpopwrk_cy                         251 non-null    int64
#  29  dpopres_cy                         251 non-null    int64
#  30  SHAPE                              251 non-null    geometry
# dtypes: float64(7), geometry(1), int64(17), object(6)
# memory usage: 60.9+ KB
#       locnum source_country   area_type buffer_units buffer_units_alias  \
# 0  177692910             US  RingBuffer    esriMiles              Miles
# 1  207178880             US  RingBuffer    esriMiles              Miles
# 2  213604069             US  RingBuffer    esriMiles              Miles
# 3  214402802             US  RingBuffer    esriMiles              Miles
# 4  215047911             US  RingBuffer    esriMiles              Miles
#
#    buffer_radii                                 aggregation_method  \
# 0             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 1             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 2             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 3             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 4             1  BlockApportionment:US.BlockGroups;PointsLayer:...
#
#    population_to_polygon_size_rating  apportionment_confidence  has_data  ...  \
# 0                              2.191                     2.576         1  ...
# 1                              2.191                     2.576         1  ...
# 2                              2.191                     2.576         1  ...
# 3                              2.191                     2.576         1  ...
# 4                              2.191                     2.576         1  ...
#
#    vacant_cy  medval_cy  avgval_cy  popgrw10_cy  hhgrw10_cy  famgrw10_cy  \
# 0        348     390413     429594         0.43        0.41         0.19
# 1        420     394983     441629         0.81        0.67         0.61
# 2       3773     628835     706736         2.86        2.81         3.17
# 3         94     376746     403178         2.64        2.52         2.44
# 4        158     575127     605756         0.41        0.47         0.20
#
#    dpop_cy  dpopwrk_cy  dpopres_cy  \
# 0    11715        4849        6866
# 1    20885        8823       12062
# 2    91264       75188       16076
# 3     5727        2799        2928
# 4    22915       18367        4548
#
#                                                SHAPE
# 0  {"x": -122.63332499999997, "y": 45.41751900000...
# 1  {"x": -122.578461, "y": 45.49077900000012, "sp...
# 2  {"x": -122.68257749999998, "y": 45.52993800000...
# 3  {"x": -122.28194789999999, "y": 45.40177785000...
# 4  {"x": -122.73786899999999, "y": 45.41748299999...
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Determine Proximity Type
#
# The above examples all use the default `proximity_type` of `straight_line`. However, based on what transportation network you have available with the GIS source you are using, other methods are also available. These can be discovered using the `travel_modes` property of the `Country`. Any of the vaues in the `names` column are valid values for `proximity_type` in addition to the default `straight_line`.

# %%
usa_agol.travel_modes
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _refresh(self)
#   14548                     dictdata = self._con.post(
# > 14549                         self.url, params
#   14550                     )  # , token=self._lazy_token)
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1259             try_json=try_json,
# -> 1260             force_bytes=kwargs.pop("force_bytes", False),
#    1261         )
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     815                 errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 816                 self._handle_json_error(data["error"], errorcode)
#     817             return data
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_json_error(self, error, errorcode)
#     838         errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 839         raise Exception(errormessage)
#     840
#
# Exception: Token Required
# (Error Code: 499)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _hydrate(self)
#   14584             try:
# > 14585                 self._refresh()
#   14586
#
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _refresh(self)
#   14556                 elif str(e).lower().find("token required") > -1:
# > 14557                     dictdata = self._con.get(self.url, params)
#   14558                 else:
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in get(self, path, params, **kwargs)
#     696             force_bytes=kwargs.pop("force_bytes", False),
# --> 697             ignore_error_key=ignore_error_key,
#     698         )
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     815                 errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 816                 self._handle_json_error(data["error"], errorcode)
#     817             return data
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_json_error(self, error, errorcode)
#     838         errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 839         raise Exception(errormessage)
#     840
#
# Exception: Token Required
# (Error Code: 499)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _refresh(self)
#   14548                     dictdata = self._con.post(
# > 14549                         self.url, params
#   14550                     )  # , token=self._lazy_token)
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1259             try_json=try_json,
# -> 1260             force_bytes=kwargs.pop("force_bytes", False),
#    1261         )
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     815                 errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 816                 self._handle_json_error(data["error"], errorcode)
#     817             return data
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_json_error(self, error, errorcode)
#     838         errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 839         raise Exception(errormessage)
#     840
#
# Exception: Token Required
# (Error Code: 499)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# d:\projects\geosaurus\src\arcgis\geoprocessing\_support.py in _execute_gp_tool(gis, task_name, params, param_db, return_values, use_async, url, webtool, add_token, return_messages, future)
#     516             try:
# --> 517                 resp = gptool._con.post(exec_url, gp_params, token=gptool._token)
#     518             except:
#
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _token(self)
#   14630         else:
# > 14631             self._hydrate()
#   14632             return self._lazy_token
#
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _hydrate(self)
#   14607                     self._lazy_token = None
# > 14608                     self._refresh()
#   14609
#
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _refresh(self)
#   14556                 elif str(e).lower().find("token required") > -1:
# > 14557                     dictdata = self._con.get(self.url, params)
#   14558                 else:
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in get(self, path, params, **kwargs)
#     696             force_bytes=kwargs.pop("force_bytes", False),
# --> 697             ignore_error_key=ignore_error_key,
#     698         )
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     815                 errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 816                 self._handle_json_error(data["error"], errorcode)
#     817             return data
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_json_error(self, error, errorcode)
#     838         errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 839         raise Exception(errormessage)
#     840
#
# Exception: Token Required
# (Error Code: 499)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12992/1559509281.py in <module>
# ----> 1 usa_agol.travel_modes
#
# d:\projects\geosaurus\src\arcgis\_impl\common\_utils.py in _lazy_property(self)
#     220     def _lazy_property(self):
#     221         if not hasattr(self, attr_name):
# --> 222             setattr(self, attr_name, fn(self))
#     223         return getattr(self, attr_name)
#     224
#
# d:\projects\geosaurus\src\arcgis\geoenrichment\enrichment.py in travel_modes(self)
#    1027
#    1028         """
# -> 1029         return self._ba_cntry.travel_modes
#    1030
#    1031
#
# d:\projects\geosaurus\src\arcgis\_impl\common\_utils.py in _lazy_property(self)
#     220     def _lazy_property(self):
#     221         if not hasattr(self, attr_name):
# --> 222             setattr(self, attr_name, fn(self))
#     223         return getattr(self, attr_name)
#     224
#
# d:\projects\geosaurus\src\arcgis\geoenrichment\_business_analyst\_utils.py in wrapped(self, *args, **kwargs)
#      70             raise NotImplementedError(f"'{self.source}' is not a recognized source.")
#      71
# ---> 72         return fn_to_call(*args, **kwargs)
#      73
#      74     return wrapped
#
# d:\projects\geosaurus\src\arcgis\geoenrichment\_business_analyst\_main.py in _travel_modes_gis(self)
#     601         """Web GIS implementation of travel modes."""
#     602         # get the travel modes FeatureSet
# --> 603         trvl_df = self._ba.travel_modes
#     604
#     605         return trvl_df
#
# d:\projects\geosaurus\src\arcgis\_impl\common\_utils.py in _lazy_property(self)
#     220     def _lazy_property(self):
#     221         if not hasattr(self, attr_name):
# --> 222             setattr(self, attr_name, fn(self))
#     223         return getattr(self, attr_name)
#     224
#
# d:\projects\geosaurus\src\arcgis\geoenrichment\_business_analyst\_utils.py in wrapped(self, *args, **kwargs)
#      70             raise NotImplementedError(f"'{self.source}' is not a recognized source.")
#      71
# ---> 72         return fn_to_call(*args, **kwargs)
#      73
#      74     return wrapped
#
# d:\projects\geosaurus\src\arcgis\geoenrichment\_business_analyst\_main.py in _travel_modes_gis(self)
#    1222         """Web GIS implementation of travel modes."""
#    1223         # get the travel modes FeatureSet
# -> 1224         trvl_fs = get_travel_modes(self.source).supported_travel_modes
#    1225
#    1226         # pluck out the travel modes metadata from the TravelMode attribute in the FeatureSet
#
# d:\projects\geosaurus\src\arcgis\network\_routing_utils.py in get_travel_modes(gis)
#      42     url = _validate_url(url, gis)
#      43     tbx = _create_toolbox(url, gis)
# ---> 44     return tbx.get_travel_modes()
#      45
#      46
#
# <string> in get_travel_modes(gis, future)
#
# d:\projects\geosaurus\src\arcgis\geoprocessing\_support.py in _execute_gp_tool(gis, task_name, params, param_db, return_values, use_async, url, webtool, add_token, return_messages, future)
#     517                 resp = gptool._con.post(exec_url, gp_params, token=gptool._token)
#     518             except:
# --> 519                 resp = gptool._con.post(exec_url, gp_params)
#     520         else:
#     521             resp = gptool._con.post(exec_url, gp_params)
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1258             file_name=file_name,
#    1259             try_json=try_json,
# -> 1260             force_bytes=kwargs.pop("force_bytes", False),
#    1261         )
#    1262
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     814                     return data
#     815                 errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 816                 self._handle_json_error(data["error"], errorcode)
#     817             return data
#     818         else:
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_json_error(self, error, errorcode)
#     837
#     838         errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 839         raise Exception(errormessage)
#     840
#     841     def post_multipart(self, path, params=None, files=None, **kwargs):
#
# Exception: Token Required
# (Error Code: 499)

# %% [markdown]
# Hence, if we want to use both paved _and_ gravel roads (because gravel roads are _fun_), we can use `rural_driving_time`. Before selecting, we can investigate the details of the method by looking at the description.

# %%
usa_agol.travel_modes[usa_agol.travel_modes.name == 'rural_driving_distance'].iloc[0]['description']
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _refresh(self)
#   14548                     dictdata = self._con.post(
# > 14549                         self.url, params
#   14550                     )  # , token=self._lazy_token)
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1259             try_json=try_json,
# -> 1260             force_bytes=kwargs.pop("force_bytes", False),
#    1261         )
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     815                 errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 816                 self._handle_json_error(data["error"], errorcode)
#     817             return data
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_json_error(self, error, errorcode)
#     838         errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 839         raise Exception(errormessage)
#     840
#
# Exception: Token Required
# (Error Code: 499)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _hydrate(self)
#   14584             try:
# > 14585                 self._refresh()
#   14586
#
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _refresh(self)
#   14556                 elif str(e).lower().find("token required") > -1:
# > 14557                     dictdata = self._con.get(self.url, params)
#   14558                 else:
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in get(self, path, params, **kwargs)
#     696             force_bytes=kwargs.pop("force_bytes", False),
# --> 697             ignore_error_key=ignore_error_key,
#     698         )
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     815                 errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 816                 self._handle_json_error(data["error"], errorcode)
#     817             return data
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_json_error(self, error, errorcode)
#     838         errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 839         raise Exception(errormessage)
#     840
#
# Exception: Token Required
# (Error Code: 499)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _refresh(self)
#   14548                     dictdata = self._con.post(
# > 14549                         self.url, params
#   14550                     )  # , token=self._lazy_token)
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1259             try_json=try_json,
# -> 1260             force_bytes=kwargs.pop("force_bytes", False),
#    1261         )
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     815                 errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 816                 self._handle_json_error(data["error"], errorcode)
#     817             return data
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_json_error(self, error, errorcode)
#     838         errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 839         raise Exception(errormessage)
#     840
#
# Exception: Token Required
# (Error Code: 499)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# d:\projects\geosaurus\src\arcgis\geoprocessing\_support.py in _execute_gp_tool(gis, task_name, params, param_db, return_values, use_async, url, webtool, add_token, return_messages, future)
#     516             try:
# --> 517                 resp = gptool._con.post(exec_url, gp_params, token=gptool._token)
#     518             except:
#
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _token(self)
#   14630         else:
# > 14631             self._hydrate()
#   14632             return self._lazy_token
#
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _hydrate(self)
#   14607                     self._lazy_token = None
# > 14608                     self._refresh()
#   14609
#
# d:\projects\geosaurus\src\arcgis\gis\__init__.py in _refresh(self)
#   14556                 elif str(e).lower().find("token required") > -1:
# > 14557                     dictdata = self._con.get(self.url, params)
#   14558                 else:
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in get(self, path, params, **kwargs)
#     696             force_bytes=kwargs.pop("force_bytes", False),
# --> 697             ignore_error_key=ignore_error_key,
#     698         )
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     815                 errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 816                 self._handle_json_error(data["error"], errorcode)
#     817             return data
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_json_error(self, error, errorcode)
#     838         errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 839         raise Exception(errormessage)
#     840
#
# Exception: Token Required
# (Error Code: 499)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12992/1285024206.py in <module>
# ----> 1 usa_agol.travel_modes[usa_agol.travel_modes.name == 'rural_driving_distance'].iloc[0]['description']
#
# d:\projects\geosaurus\src\arcgis\_impl\common\_utils.py in _lazy_property(self)
#     220     def _lazy_property(self):
#     221         if not hasattr(self, attr_name):
# --> 222             setattr(self, attr_name, fn(self))
#     223         return getattr(self, attr_name)
#     224
#
# d:\projects\geosaurus\src\arcgis\geoenrichment\enrichment.py in travel_modes(self)
#    1027
#    1028         """
# -> 1029         return self._ba_cntry.travel_modes
#    1030
#    1031
#
# d:\projects\geosaurus\src\arcgis\_impl\common\_utils.py in _lazy_property(self)
#     220     def _lazy_property(self):
#     221         if not hasattr(self, attr_name):
# --> 222             setattr(self, attr_name, fn(self))
#     223         return getattr(self, attr_name)
#     224
#
# d:\projects\geosaurus\src\arcgis\geoenrichment\_business_analyst\_utils.py in wrapped(self, *args, **kwargs)
#      70             raise NotImplementedError(f"'{self.source}' is not a recognized source.")
#      71
# ---> 72         return fn_to_call(*args, **kwargs)
#      73
#      74     return wrapped
#
# d:\projects\geosaurus\src\arcgis\geoenrichment\_business_analyst\_main.py in _travel_modes_gis(self)
#     601         """Web GIS implementation of travel modes."""
#     602         # get the travel modes FeatureSet
# --> 603         trvl_df = self._ba.travel_modes
#     604
#     605         return trvl_df
#
# d:\projects\geosaurus\src\arcgis\_impl\common\_utils.py in _lazy_property(self)
#     220     def _lazy_property(self):
#     221         if not hasattr(self, attr_name):
# --> 222             setattr(self, attr_name, fn(self))
#     223         return getattr(self, attr_name)
#     224
#
# d:\projects\geosaurus\src\arcgis\geoenrichment\_business_analyst\_utils.py in wrapped(self, *args, **kwargs)
#      70             raise NotImplementedError(f"'{self.source}' is not a recognized source.")
#      71
# ---> 72         return fn_to_call(*args, **kwargs)
#      73
#      74     return wrapped
#
# d:\projects\geosaurus\src\arcgis\geoenrichment\_business_analyst\_main.py in _travel_modes_gis(self)
#    1222         """Web GIS implementation of travel modes."""
#    1223         # get the travel modes FeatureSet
# -> 1224         trvl_fs = get_travel_modes(self.source).supported_travel_modes
#    1225
#    1226         # pluck out the travel modes metadata from the TravelMode attribute in the FeatureSet
#
# d:\projects\geosaurus\src\arcgis\network\_routing_utils.py in get_travel_modes(gis)
#      42     url = _validate_url(url, gis)
#      43     tbx = _create_toolbox(url, gis)
# ---> 44     return tbx.get_travel_modes()
#      45
#      46
#
# <string> in get_travel_modes(gis, future)
#
# d:\projects\geosaurus\src\arcgis\geoprocessing\_support.py in _execute_gp_tool(gis, task_name, params, param_db, return_values, use_async, url, webtool, add_token, return_messages, future)
#     517                 resp = gptool._con.post(exec_url, gp_params, token=gptool._token)
#     518             except:
# --> 519                 resp = gptool._con.post(exec_url, gp_params)
#     520         else:
#     521             resp = gptool._con.post(exec_url, gp_params)
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1258             file_name=file_name,
#    1259             try_json=try_json,
# -> 1260             force_bytes=kwargs.pop("force_bytes", False),
#    1261         )
#    1262
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#     814                     return data
#     815                 errorcode = data["error"]["code"] if "code" in data["error"] else 0
# --> 816                 self._handle_json_error(data["error"], errorcode)
#     817             return data
#     818         else:
#
# d:\projects\geosaurus\src\arcgis\gis\_impl\_con\_connection.py in _handle_json_error(self, error, errorcode)
#     837
#     838         errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# --> 839         raise Exception(errormessage)
#     840
#     841     def post_multipart(self, path, params=None, files=None, **kwargs):
#
# Exception: Token Required
# (Error Code: 499)

# %% [markdown]
# ### Enrich using Proximity Parameters
#
# _Most_ people aren't going to be driving as fast on a gravel road as they are on an interstate. This enables us to take into consideration the differences in speed based on the road type. Using drive time as a method to define proximity around a location is a much better represenation of how people actually move around and interact with their surrouding environemnt...such as finding food at a grocery store.

# %%
pt4_enrich_df = usa_agol.enrich(
    geographies=pt_df,
    enrich_variables=kv,
    proximity_type='rural_driving_time',
    proximity_value=8,
    proximity_metric='minutes'
)

pt4_enrich_df.info()
pt4_enrich_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   locnum                             251 non-null    object
#  1   source_country                     251 non-null    object
#  2   area_type                          251 non-null    object
#  3   buffer_units                       251 non-null    object
#  4   buffer_units_alias                 251 non-null    object
#  5   buffer_radii                       251 non-null    int64
#  6   aggregation_method                 251 non-null    object
#  7   population_to_polygon_size_rating  251 non-null    float64
#  8   apportionment_confidence           251 non-null    float64
#  9   has_data                           251 non-null    int64
#  10  totpop_cy                          251 non-null    int64
#  11  gqpop_cy                           251 non-null    int64
#  12  divindx_cy                         251 non-null    float64
#  13  tothh_cy                           251 non-null    int64
#  14  avghhsz_cy                         251 non-null    float64
#  15  medhinc_cy                         251 non-null    int64
#  16  avghinc_cy                         251 non-null    int64
#  17  pci_cy                             251 non-null    int64
#  18  tothu_cy                           251 non-null    int64
#  19  owner_cy                           251 non-null    int64
#  20  renter_cy                          251 non-null    int64
#  21  vacant_cy                          251 non-null    int64
#  22  medval_cy                          251 non-null    int64
#  23  avgval_cy                          251 non-null    int64
#  24  popgrw10_cy                        251 non-null    float64
#  25  hhgrw10_cy                         251 non-null    float64
#  26  famgrw10_cy                        251 non-null    float64
#  27  dpop_cy                            251 non-null    int64
#  28  dpopwrk_cy                         251 non-null    int64
#  29  dpopres_cy                         251 non-null    int64
#  30  SHAPE                              251 non-null    geometry
# dtypes: float64(7), geometry(1), int64(17), object(6)
# memory usage: 60.9+ KB
#       locnum source_country   area_type buffer_units buffer_units_alias  \
# 0  177692910             US  RingBuffer    esriMiles              Miles
# 1  207178880             US  RingBuffer    esriMiles              Miles
# 2  213604069             US  RingBuffer    esriMiles              Miles
# 3  214402802             US  RingBuffer    esriMiles              Miles
# 4  215047911             US  RingBuffer    esriMiles              Miles
#
#    buffer_radii                                 aggregation_method  \
# 0             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 1             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 2             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 3             1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 4             1  BlockApportionment:US.BlockGroups;PointsLayer:...
#
#    population_to_polygon_size_rating  apportionment_confidence  has_data  ...  \
# 0                              2.191                     2.576         1  ...
# 1                              2.191                     2.576         1  ...
# 2                              2.191                     2.576         1  ...
# 3                              2.191                     2.576         1  ...
# 4                              2.191                     2.576         1  ...
#
#    vacant_cy  medval_cy  avgval_cy  popgrw10_cy  hhgrw10_cy  famgrw10_cy  \
# 0        348     390413     429594         0.43        0.41         0.19
# 1        420     394983     441629         0.81        0.67         0.61
# 2       3773     628835     706736         2.86        2.81         3.17
# 3         94     376746     403178         2.64        2.52         2.44
# 4        158     575127     605756         0.41        0.47         0.20
#
#    dpop_cy  dpopwrk_cy  dpopres_cy  \
# 0    11715        4849        6866
# 1    20885        8823       12062
# 2    91264       75188       16076
# 3     5727        2799        2928
# 4    22915       18367        4548
#
#                                                SHAPE
# 0  {"x": -122.63332499999997, "y": 45.41751900000...
# 1  {"x": -122.578461, "y": 45.49077900000012, "sp...
# 2  {"x": -122.68257749999998, "y": 45.52993800000...
# 3  {"x": -122.28194789999999, "y": 45.40177785000...
# 4  {"x": -122.73786899999999, "y": 45.41748299999...
#
# [5 rows x 31 columns]
