# %% [markdown]
# # ArcMap Spatial Overlay Variable String to ArcGIS Pro Enrich Layers Input

# %%
from arcgis.geoenrichment import Country

# %% [markdown]
# ## Convert the String to a List

# %%
var_str = """
'TOTPOP_CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)';'HHPOP_CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)';'FAMPOP_CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)';'MP14129a_B.2021 Health (Market Potential) (Esri USA 2021)';'X11001_X.2021 Education (Consumer Spending) (Esri USA 2021)';'X11001_A.2021 Education (Consumer Spending) (Esri USA 2021)';'X11001_I.2021 Education (Consumer Spending) (Esri USA 2021)';'MP09147a_B.2021 Electronics (Market Potential) (Esri USA 2021)';'MP09147a_I.2021 Electronics (Market Potential) (Esri USA 2021)';'MP09148a_B.2021 Electronics (Market Potential) (Esri USA 2021)';'MP09148a_I.2021 Electronics (Market Potential) (Esri USA 2021)';'MP09134a_B.2021 Electronics (Market Potential) (Esri USA 2021)';'MP09134a_I.2021 Electronics (Market Potential) (Esri USA 2021)';'ACSTOTPOP.2015-2019 Key Demographic Indicators (ACS) (Esri USA 2021 ACS)';'MOETOTPOP.2015-2019 Key Demographic Indicators (ACS) (Esri USA 2021 ACS)';'RELTOTPOP.2015-2019 Key Demographic Indicators (ACS) (Esri USA 2021 ACS)';'INDAGRI_CY.2021 Labor Force (Esri) (US 2021 Retail MarketPlace)';'INDMIN_CY.2021 Labor Force (Esri) (US 2021 Retail MarketPlace)';'INDCONS_CY.2021 Labor Force (Esri) (US 2021 Retail MarketPlace)';'HHWHTHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';'HHBLKHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';'HHAIHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';'HHASNHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';'HHPIHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';'HHOTHHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';TADULTBASE.2021 Tapestry Market Segmentation (Adults) (Esri USA 2021)';'TADULT01.2021 Tapestry Market Segmentation (Adults) (Esri USA 2021)';TADULT02.2021 Tapestry Market Segmentation (Adults) (Esri USA 2021)';'POPGRW10CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)';'DIVINDX_CY.2021 Race and Hispanic Origin (Esri) (Esri USA 2021)';'MEDHINC_CY.2021 Income (Esri) (Esri USA 2021)'
"""

var_str
# Out:
# "\n'TOTPOP_CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)';'HHPOP_CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)';'FAMPOP_CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)';'MP14129a_B.2021 Health (Market Potential) (Esri USA 2021)';'X11001_X.2021 Education (Consumer Spending) (Esri USA 2021)';'X11001_A.2021 Education (Consumer Spending) (Esri USA 2021)';'X11001_I.2021 Education (Consumer Spending) (Esri USA 2021)';'MP09147a_B.2021 Electronics (Market Potential) (Esri USA 2021)';'MP09147a_I.2021 Electronics (Market Potential) (Esri USA 2021)';'MP09148a_B.2021 Electronics (Market Potential) (Esri USA 2021)';'MP09148a_I.2021 Electronics (Market Potential) (Esri USA 2021)';'MP09134a_B.2021 Electronics (Market Potential) (Esri USA 2021)';'MP09134a_I.2021 Electronics (Market Potential) (Esri USA 2021)';'ACSTOTPOP.2015-2019 Key Demographic Indicators (ACS) (Esri USA 2021 ACS)';'MOETOTPOP.2015-2019 Key Demographic Indicators (ACS) (Esri USA 2021 ACS)';'RELTOTPOP.2015-2019 Key Demographic Indicators (ACS) (Esri USA 2021 ACS)';'INDAGRI_CY.2021 Labor Force (Esri) (US 2021 Retail MarketPlace)';'INDMIN_CY.2021 Labor Force (Esri) (US 2021 Retail MarketPlace)';'INDCONS_CY.2021 Labor Force (Esri) (US 2021 Retail MarketPlace)';'HHWHTHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';'HHBLKHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';'HHAIHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';'HHASNHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';'HHPIHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';'HHOTHHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)';TADULTBASE.2021 Tapestry Market Segmentation (Adults) (Esri USA 2021)';'TADULT01.2021 Tapestry Market Segmentation (Adults) (Esri USA 2021)';TADULT02.2021 Tapestry Market Segmentation (Adults) (Esri USA 2021)';'POPGRW10CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)';'DIVINDX_CY.2021 Race and Hispanic Origin (Esri) (Esri USA 2021)';'MEDHINC_CY.2021 Income (Esri) (Esri USA 2021)'\n"

# %%
var_lst = var_str.replace("'", "").strip().split(';')

var_lst
# Out:
# ['TOTPOP_CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)',
#  'HHPOP_CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)',
#  'FAMPOP_CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)',
#  'MP14129a_B.2021 Health (Market Potential) (Esri USA 2021)',
#  'X11001_X.2021 Education (Consumer Spending) (Esri USA 2021)',
#  'X11001_A.2021 Education (Consumer Spending) (Esri USA 2021)',
#  'X11001_I.2021 Education (Consumer Spending) (Esri USA 2021)',
#  'MP09147a_B.2021 Electronics (Market Potential) (Esri USA 2021)',
#  'MP09147a_I.2021 Electronics (Market Potential) (Esri USA 2021)',
#  'MP09148a_B.2021 Electronics (Market Potential) (Esri USA 2021)',
#  'MP09148a_I.2021 Electronics (Market Potential) (Esri USA 2021)',
#  'MP09134a_B.2021 Electronics (Market Potential) (Esri USA 2021)',
#  'MP09134a_I.2021 Electronics (Market Potential) (Esri USA 2021)',
#  'ACSTOTPOP.2015-2019 Key Demographic Indicators (ACS) (Esri USA 2021 ACS)',
#  'MOETOTPOP.2015-2019 Key Demographic Indicators (ACS) (Esri USA 2021 ACS)',
#  'RELTOTPOP.2015-2019 Key Demographic Indicators (ACS) (Esri USA 2021 ACS)',
#  'INDAGRI_CY.2021 Labor Force (Esri) (US 2021 Retail MarketPlace)',
#  'INDMIN_CY.2021 Labor Force (Esri) (US 2021 Retail MarketPlace)',
#  'INDCONS_CY.2021 Labor Force (Esri) (US 2021 Retail MarketPlace)',
#  'HHWHTHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)',
#  'HHBLKHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)',
#  'HHAIHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)',
#  'HHASNHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)',
#  'HHPIHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)',
#  'HHOTHHHR10.2010 Households by Race_Hispanic Origin (U_S_ Census) (US 2021 Retail MarketPlace)',
#  'TADULTBASE.2021 Tapestry Market Segmentation (Adults) (Esri USA 2021)',
#  'TADULT01.2021 Tapestry Market Segmentation (Adults) (Esri USA 2021)',
#  'TADULT02.2021 Tapestry Market Segmentation (Adults) (Esri USA 2021)',
#  'POPGRW10CY.2021 Key Demographic Indicators (Esri) (Esri USA 2021)',
#  'DIVINDX_CY.2021 Race and Hispanic Origin (Esri) (Esri USA 2021)',
#  'MEDHINC_CY.2021 Income (Esri) (Esri USA 2021)']

# %%
nm_lst = [var.split('.')[0] for var in var_lst]

nm_lst
# Out:
# ['TOTPOP_CY',
#  'HHPOP_CY',
#  'FAMPOP_CY',
#  'MP14129a_B',
#  'X11001_X',
#  'X11001_A',
#  'X11001_I',
#  'MP09147a_B',
#  'MP09147a_I',
#  'MP09148a_B',
#  'MP09148a_I',
#  'MP09134a_B',
#  'MP09134a_I',
#  'ACSTOTPOP',
#  'MOETOTPOP',
#  'RELTOTPOP',
#  'INDAGRI_CY',
#  'INDMIN_CY',
#  'INDCONS_CY',
#  'HHWHTHHR10',
#  'HHBLKHHR10',
#  'HHAIHHR10',
#  'HHASNHHR10',
#  'HHPIHHR10',
#  'HHOTHHHR10',
#  'TADULTBASE',
#  'TADULT01',
#  'TADULT02',
#  'POPGRW10CY',
#  'DIVINDX_CY',
#  'MEDHINC_CY']

# %% [markdown]
# ## Look Up the Variables from the List

# %%
usa = Country('usa')

usa
# Out:
# <Country - United States (GIS @ https://www.arcgis.com version:10.1)>

# %%
var_df = usa._ba_cntry.get_enrich_variables_from_iterable(nm_lst)

var_df
# Out:
#           name                                           alias  \
# 0    MOETOTPOP            2019 Total Population MOE (ACS 5-Yr)
# 1    TOTPOP_CY                           2021 Total Population
# 2   TADULTBASE                    2021 Tapestry Adult Pop Base
# 3     X11001_A                             2021 Avg: Education
# 4     X11001_I                           2021 Index: Education
# 5   MP09147a_B                             2021 Own Any Tablet
# 6   MP09147a_I                      2021 Index: Own Any Tablet
# 7   MP09148a_B                           2021 Own Any E-Reader
# 8   MP09148a_I                    2021 Index: Own Any E-Reader
# 9   MP09134a_B         2021 Own E-Reader/Tablet: Amazon Kindle
# 10  MP09134a_I  2021 Index: Own E-Reader/Tablet: Amazon Kindle
# 11  MEDHINC_CY                    2021 Median Household Income
# 12  MP14129a_B      2021 Typically Spend 1-3 Hrs Exercising/Wk
# 13  DIVINDX_CY                            2021 Diversity Index
# 14  POPGRW10CY               2010-2021 Growth Rate: Population
# 15    X11001_X                                  2021 Education
# 16  HHWHTHHR10                            2010 HHs w/White HHr
# 17  HHBLKHHR10                            2010 HHs w/Black HHr
# 18   HHAIHHR10                      2010 HHs w/Amer Indian HHr
# 19  HHASNHHR10                            2010 HHs w/Asian HHr
# 20   HHPIHHR10                      2010 HHs w/Pacific Isl HHr
# 21  HHOTHHHR10                       2010 HHs w/Other Race HHr
# 22  INDAGRI_CY                      2021 Industry: Agriculture
# 23   INDMIN_CY                           2021 Industry: Mining
# 24  INDCONS_CY                     2021 Industry: Construction
# 25   ACSTOTPOP                2019 Total Population (ACS 5-Yr)
# 26   RELTOTPOP            2019 Total Population REL (ACS 5-Yr)
# 27    HHPOP_CY                       2021 Household Population
# 28   FAMPOP_CY                          2021 Family Population
# 29    TADULT01                 2021 Pop 18+ in Tapestry Seg 1A
# 30    TADULT02                 2021 Pop 18+ in Tapestry Seg 1B
#
#                   data_collection                               enrich_name  \
# 0         ACS_Housing_Summary_rep         ACS_Housing_Summary_rep.MOETOTPOP
# 1                          AtRisk                          AtRisk.TOTPOP_CY
# 2                          AtRisk                         AtRisk.TADULTBASE
# 3           Community_Profile_rep            Community_Profile_rep.X11001_A
# 4           Community_Profile_rep            Community_Profile_rep.X11001_I
# 5             ElectronicsInternet            ElectronicsInternet.MP09147a_B
# 6             ElectronicsInternet            ElectronicsInternet.MP09147a_I
# 7             ElectronicsInternet            ElectronicsInternet.MP09148a_B
# 8             ElectronicsInternet            ElectronicsInternet.MP09148a_I
# 9             ElectronicsInternet            ElectronicsInternet.MP09134a_B
# 10            ElectronicsInternet            ElectronicsInternet.MP09134a_I
# 11                         Health                         Health.MEDHINC_CY
# 12             HealthPersonalCare             HealthPersonalCare.MP14129a_B
# 13                     KeyUSFacts                     KeyUSFacts.DIVINDX_CY
# 14                     KeyUSFacts                     KeyUSFacts.POPGRW10CY
# 15                      education                        education.X11001_X
# 16  householdsbyraceofhouseholder  householdsbyraceofhouseholder.HHWHTHHR10
# 17  householdsbyraceofhouseholder  householdsbyraceofhouseholder.HHBLKHHR10
# 18  householdsbyraceofhouseholder   householdsbyraceofhouseholder.HHAIHHR10
# 19  householdsbyraceofhouseholder  householdsbyraceofhouseholder.HHASNHHR10
# 20  householdsbyraceofhouseholder   householdsbyraceofhouseholder.HHPIHHR10
# 21  householdsbyraceofhouseholder  householdsbyraceofhouseholder.HHOTHHHR10
# 22                       industry                       industry.INDAGRI_CY
# 23                       industry                        industry.INDMIN_CY
# 24                       industry                       industry.INDCONS_CY
# 25                     population                      population.ACSTOTPOP
# 26                     population                      population.RELTOTPOP
# 27               populationtotals                 populationtotals.HHPOP_CY
# 28               populationtotals                populationtotals.FAMPOP_CY
# 29              tapestryadultsNEW                tapestryadultsNEW.TADULT01
# 30              tapestryadultsNEW                tapestryadultsNEW.TADULT02
#
#                            enrich_field_name  \
# 0          ACS_Housing_Summary_rep_MOETOTPOP
# 1                           AtRisk_TOTPOP_CY
# 2                          AtRisk_TADULTBASE
# 3             Community_Profile_rep_X11001_A
# 4             Community_Profile_rep_X11001_I
# 5             ElectronicsInternet_MP09147a_B
# 6             ElectronicsInternet_MP09147a_I
# 7             ElectronicsInternet_MP09148a_B
# 8             ElectronicsInternet_MP09148a_I
# 9             ElectronicsInternet_MP09134a_B
# 10            ElectronicsInternet_MP09134a_I
# 11                         Health_MEDHINC_CY
# 12             HealthPersonalCare_MP14129a_B
# 13                     KeyUSFacts_DIVINDX_CY
# 14                     KeyUSFacts_POPGRW10CY
# 15                        education_X11001_X
# 16  householdsbyraceofhouseholder_HHWHTHHR10
# 17  householdsbyraceofhouseholder_HHBLKHHR10
# 18   householdsbyraceofhouseholder_HHAIHHR10
# 19  householdsbyraceofhouseholder_HHASNHHR10
# 20   householdsbyraceofhouseholder_HHPIHHR10
# 21  householdsbyraceofhouseholder_HHOTHHHR10
# 22                       industry_INDAGRI_CY
# 23                        industry_INDMIN_CY
# 24                       industry_INDCONS_CY
# 25                      population_ACSTOTPOP
# 26                      population_RELTOTPOP
# 27                 populationtotals_HHPOP_CY
# 28                populationtotals_FAMPOP_CY
# 29                tapestryadultsNEW_TADULT01
# 30                tapestryadultsNEW_TADULT02
#
#                                           description    vintage     units
# 0                2019 Total Population MOE (ACS 5-Yr)  2015-2019     count
# 1                        2021 Total Population (Esri)       2021     count
# 2   2021 Base for Tapestry Segmentation Adult Popu...       2021     count
# 3                             2021 Education: Average       2021  currency
# 4                               2021 Education: Index       2021     count
# 5                                 2021 Own Any Tablet       2021     count
# 6                          2021 Own Any Tablet: Index       2021     count
# 7                               2021 Own Any E-Reader       2021     count
# 8                        2021 Own Any E-Reader: Index       2021     count
# 9          2021 Own E-Reader or Tablet: Amazon Kindle       2021     count
# 10  2021 Own E-Reader or Tablet: Amazon Kindle: Index       2021     count
# 11                2021 Median Household Income (Esri)       2021  currency
# 12  2021 Typically Spend 1-3 Hours Exercising Per ...       2021     count
# 13                        2021 Diversity Index (Esri)       2021     count
# 14  2010-2021 Population: Compound Annual Growth R...       2021       pct
# 15                                     2021 Education       2021  currency
# 16  2010 Households w/White Householder (U.S. Census)       2010     count
# 17  2010 Households w/Black/African American House...       2010     count
# 18  2010 Households w/American Indian/Alaska Nativ...       2010     count
# 19  2010 Households w/Asian Householder (U.S. Census)       2010     count
# 20  2010 Households w/Pacific Islander Householder...       2010     count
# 21  2010 Households w/Other Race Householder (U.S....       2010     count
# 22  2021 Industry: Agriculture/Forestry/Fishing/Hu...       2021     count
# 23  2021 Industry: Mining/Quarrying/Oil & Gas Extr...       2021     count
# 24                 2021 Industry: Construction (Esri)       2021     count
# 25                   2019 Total Population (ACS 5-Yr)  2015-2019     count
# 26               2019 Total Population REL (ACS 5-Yr)  2015-2019     count
# 27                   2021 Household Population (Esri)       2021     count
# 28                      2021 Family Population (Esri)       2021     count
# 29  2021 Top Tier (1A) Tapestry Adult Population (...       2021     count
# 30  2021 Professional Pride (1B) Tapestry Adult Po...       2021     count

# %% [markdown]
# ## Get the Semicolon Delimited String for Input to the Enrich Layer Tool

# %%
';'.join(var_df.enrich_name.values)
# Out:
# 'Health.MEDHINC_CY;ACS_Housing_Summary_rep.MOETOTPOP;travelMPI.TADULTBASE;Age_by_Sex_by_Race_Profile_rep.TOTPOP_CY;Policy.DIVINDX_CY;Community_Profile_rep.X11001_I;ElectronicsInternet.MP09147a_B;ElectronicsInternet.MP09147a_I;ElectronicsInternet.MP09148a_B;ElectronicsInternet.MP09148a_I;ElectronicsInternet.MP09134a_B;ElectronicsInternet.MP09134a_I;education.X11001_X;education.X11001_A;HealthPersonalCare.MP14129a_B;industry.INDAGRI_CY;industry.INDMIN_CY;industry.INDCONS_CY;householdsbyraceofhouseholder.HHWHTHHR10;householdsbyraceofhouseholder.HHBLKHHR10;householdsbyraceofhouseholder.HHAIHHR10;householdsbyraceofhouseholder.HHASNHHR10;householdsbyraceofhouseholder.HHPIHHR10;householdsbyraceofhouseholder.HHOTHHHR10;KeyUSFacts.POPGRW10CY;tapestryadultsNEW.TADULT01;tapestryadultsNEW.TADULT02;population.ACSTOTPOP;population.RELTOTPOP;populationtotals.HHPOP_CY;populationtotals.FAMPOP_CY'
