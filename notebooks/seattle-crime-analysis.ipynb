# %%
from datetime import datetime
import os
from pathlib import Path
from typing import Tuple

from arcgis.features import FeatureLayer
from arcgis.gis import GIS
from arcgis.geoenrichment import Country
from dotenv import find_dotenv, load_dotenv
import numpy as np
import pandas as pd
from sodapy import Socrata
from sklearn.linear_model import LinearRegression

# %%
# using python-dotenv to load credentials from .env file as environment variables
load_dotenv(find_dotenv())

# variables for finding resources
mcpp_url = 'https://gisdata.seattle.gov/server/rest/services/SPD/SPD/MapServer/4'
seattle_socrata_url = 'data.seattle.gov'
crime_socrata_id = 'tazs-3rd5'

# useful paths
dir_prj = Path.cwd().parent
dir_data = dir_prj/'data'
dir_int = dir_data/'interim'

# path to where crime data is cached
crime_df_pth = dir_int/'crime_df.pickle'

# %% [markdown]
# ## Download Data From Seattle Open Data
#
# Seattle uses Socrata and ArcGIS Open Data to provide open data resources. The crime data is only available through Socrata, so we can use the `Socrata` object from the `sodapy` package to retrieve the data as a list of JSON objects. From there we can convert these JSON objects to a Pandas data frame for subsequent analysis.

# %%
# get today's date to work backwards from
today = datetime.today()

start_year = today.year - 1  # start one year ago
start_month = today.month - 1  # one month back since data typically is available for last month

# example of how to format string - used below to create SoQL query string for Socrata request
f'{start_year}-{start_month:02d}-01'
# Out:
# '2021-05-01'

# %%
# if the cached data does not exist
if not crime_df_pth.exists():

    # create a connection to Seattle Socrata
    socrata = Socrata(seattle_socrata_url, 
                      app_token=os.getenv('SEATTLE_SOCRATA_APP_TOKEN'), 
                      username=os.getenv('SEATTLE_SOCRATA_API_KEY'), 
                      password=os.getenv('SEATTLE_SOCRATA_SECRET_KEY')
                     )

    # get all the data - since requires pagnation, this only returns a generator to get all the data
    crime_gen = socrata.get_all(crime_socrata_id, 
                            where=f"offense_start_datetime >= '{start_year}-{start_month:02d}-01'"
                           )

    # create a pandas data frame by loading from the get_all - forces the generator to execute
    crime_df = pd.DataFrame.from_dict(crime_gen)
    
    # convert the start date time to a real datetime and set as the index
    crime_df['offense_start_datetime'] = pd.to_datetime(crime_df['offense_start_datetime'])
    crime_df.set_index('offense_start_datetime', inplace=True)
    
    # cache the results for later runs
    crime_df.to_pickle(crime_df_pth)

# if the cached data already exists, just load it
else:
    crime_df = pd.read_pickle(crime_df_pth)
    
# make sure data is for time period we are interested in since I've sometimes cached data from way further back
crime_df = crime_df.loc[crime_df.index >= (today - pd.DateOffset(years=1, months=1))]

# ensure no leading or trailing spaces in the mcpp column
crime_df.mcpp = crime_df.mcpp.str.strip()

# fix typo encountered in data
crime_df.mcpp = crime_df.mcpp.str.replace('CAPTIOL', 'CAPITOL')
    
crime_df.info()
crime_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 80408 entries, 2021-05-02 07:00:00 to 2022-05-31 17:57:00
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   report_number           80408 non-null  object
#  1   offense_id              80408 non-null  object
#  2   offense_end_datetime    58042 non-null  object
#  3   report_datetime         80408 non-null  object
#  4   group_a_b               80408 non-null  object
#  5   crime_against_category  80408 non-null  object
#  6   offense_parent_group    80408 non-null  object
#  7   offense                 80408 non-null  object
#  8   offense_code            80408 non-null  object
#  9   precinct                80405 non-null  object
#  10  sector                  80408 non-null  object
#  11  beat                    80408 non-null  object
#  12  mcpp                    80408 non-null  object
#  13  _100_block_address      74305 non-null  object
#  14  longitude               80408 non-null  object
#  15  latitude                80408 non-null  object
# dtypes: object(16)
# memory usage: 10.4+ MB
#                        report_number   offense_id     offense_end_datetime  \
# offense_start_datetime
# 2021-05-02 07:00:00      2021-108318  23602074746  2021-05-02T20:00:00.000
# 2021-05-02 07:15:00      2021-106702  23535159984  2021-05-02T07:36:00.000
# 2021-05-02 07:19:00      2021-106691  23535110645                      NaN
# 2021-05-02 07:33:00      2021-106699  23542485285  2021-05-02T07:33:00.000
# 2021-05-02 07:33:00      2021-106699  23558879881  2021-05-02T07:33:00.000
#
#                                 report_datetime group_a_b  \
# offense_start_datetime
# 2021-05-02 07:00:00     2021-05-04T06:04:30.000         A
# 2021-05-02 07:15:00     2021-05-02T09:13:50.000         A
# 2021-05-02 07:19:00     2021-05-02T09:16:28.000         A
# 2021-05-02 07:33:00     2021-05-02T11:04:56.000         A
# 2021-05-02 07:33:00     2021-05-02T11:04:56.000         A
#
#                        crime_against_category  \
# offense_start_datetime
# 2021-05-02 07:00:00                  PROPERTY
# 2021-05-02 07:15:00                  PROPERTY
# 2021-05-02 07:19:00                  PROPERTY
# 2021-05-02 07:33:00                  PROPERTY
# 2021-05-02 07:33:00                  PROPERTY
#
#                                             offense_parent_group  \
# offense_start_datetime
# 2021-05-02 07:00:00                          MOTOR VEHICLE THEFT
# 2021-05-02 07:15:00                   BURGLARY/BREAKING&ENTERING
# 2021-05-02 07:19:00                                LARCENY-THEFT
# 2021-05-02 07:33:00     DESTRUCTION/DAMAGE/VANDALISM OF PROPERTY
# 2021-05-02 07:33:00                                      ROBBERY
#
#                                                          offense offense_code  \
# offense_start_datetime
# 2021-05-02 07:00:00                          Motor Vehicle Theft          240
# 2021-05-02 07:15:00                 Burglary/Breaking & Entering          220
# 2021-05-02 07:19:00                                  Shoplifting          23C
# 2021-05-02 07:33:00     Destruction/Damage/Vandalism of Property          290
# 2021-05-02 07:33:00                                      Robbery          120
#
#                        precinct sector beat                      mcpp  \
# offense_start_datetime
# 2021-05-02 07:00:00           S      O   O2                GEORGETOWN
# 2021-05-02 07:15:00           E      E   E2              CAPITOL HILL
# 2021-05-02 07:19:00           E      C   C3  CENTRAL AREA/SQUIRE PARK
# 2021-05-02 07:33:00           S      R   R3             COLUMBIA CITY
# 2021-05-02 07:33:00           S      R   R3             COLUMBIA CITY
#
#                                 _100_block_address       longitude  \
# offense_start_datetime
# 2021-05-02 07:00:00         1ST AVE S / S ORCAS ST  -122.334216046
# 2021-05-02 07:15:00     18XX BLOCK OF BOYLSTON AVE  -122.323447280
# 2021-05-02 07:19:00     22XX BLOCK OF E MADISON ST  -122.303098800
# 2021-05-02 07:33:00     36XX BLOCK OF S EDMUNDS ST  -122.286913708
# 2021-05-02 07:33:00     36XX BLOCK OF S EDMUNDS ST  -122.286913708
#
#                             latitude
# offense_start_datetime
# 2021-05-02 07:00:00     47.551903260
# 2021-05-02 07:15:00     47.617653300
# 2021-05-02 07:19:00     47.618795460
# 2021-05-02 07:33:00     47.558659550
# 2021-05-02 07:33:00     47.558659550

# %%
crime_mcpp_dt_srs = crime_df.groupby(['mcpp', pd.Grouper(freq='W')]).size()
crime_mcpp_dt_srs.name = 'crime_count'
crime_mcpp_dt_df = crime_mcpp_dt_srs.reset_index()

# remove unknown
crime_mcpp_dt_df = crime_mcpp_dt_df.loc[crime_mcpp_dt_df.mcpp != 'UNKNOWN']

crime_mcpp_dt_df.info()
crime_mcpp_dt_df.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3262 entries, 0 to 3319
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   mcpp                    3262 non-null   object
#  1   offense_start_datetime  3262 non-null   datetime64[ns]
#  2   crime_count             3262 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 101.9+ KB
#                                 mcpp offense_start_datetime  crime_count
# 1989                          MORGAN             2021-12-26            5
# 294                       BITTERLAKE             2021-06-20           22
# 454                     CAPITOL HILL             2022-04-24           80
# 1448  JUDKINS PARK/NORTH BEACON HILL             2021-06-27           13
# 3192                      UNIVERSITY             2022-03-20           51

# %%
mcpp_lyr = FeatureLayer(mcpp_url)

mcpp_lyr
# Out:
# <FeatureLayer url:"https://gisdata.seattle.gov/server/rest/services/SPD/SPD/MapServer/4">

# %%
mcpp_df = mcpp_lyr.query(out_fields='NEIGHBORHOOD', out_sr=4326).sdf.drop(columns='OBJECTID')
mcpp_df.columns = ['mcpp', 'SHAPE']
mcpp_df.spatial.set_geometry('SHAPE')
assert mcpp_df.spatial.validate()

mcpp_df.info()
mcpp_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mcpp    58 non-null     string
#  1   SHAPE   58 non-null     geometry
# dtypes: geometry(1), string(1)
# memory usage: 1.0 KB
#               mcpp                                              SHAPE
# 0  ALASKA JUNCTION  {"rings": [[[-122.37346169215971, 47.569868845...
# 1             ALKI  {"rings": [[[-122.37241408619865, 47.588688879...
# 2    BALLARD NORTH  {"rings": [[[-122.36607680181163, 47.705160617...
# 3    BALLARD SOUTH  {"rings": [[[-122.36602339866104, 47.675985346...
# 4         BELLTOWN  {"rings": [[[-122.3513600695938, 47.6185863995...

# %%
gis = GIS(os.getenv('ESRI_GIS_URL'), username=os.getenv('ESRI_GIS_USERNAME'), password=os.getenv('ESRI_GIS_PASSWORD'))

gis
# Out:
# GIS @ https://baqa.mapsqa.arcgis.com version:10.1

# %%
usa = Country('usa', gis=gis)

usa
# Out:
# <Country - United States (GIS @ https://baqa.mapsqa.arcgis.com version:10.1)>

# %%
ev_df = usa.enrich_variables[
    (usa.enrich_variables.data_collection.str.lower().str.contains('key'))  # "key" data collection
    & (usa.enrich_variables.name.str.lower().str.endswith('cy'))  # current year variables
].drop_duplicates('name').reset_index(drop=True)  # ensure no duplicates (possible if pulling from multiple data collections)

# set the index to the name in lowercase
ev_df.index = ev_df.name.str.lower()

ev_df
# Out:
#                   name                              alias data_collection  \
# name
# totpop_cy    TOTPOP_CY              2021 Total Population      KeyUSFacts
# gqpop_cy      GQPOP_CY     2021 Group Quarters Population      KeyUSFacts
# divindx_cy  DIVINDX_CY               2021 Diversity Index      KeyUSFacts
# tothh_cy      TOTHH_CY              2021 Total Households      KeyUSFacts
# avghhsz_cy  AVGHHSZ_CY        2021 Average Household Size      KeyUSFacts
# medhinc_cy  MEDHINC_CY       2021 Median Household Income      KeyUSFacts
# avghinc_cy  AVGHINC_CY      2021 Average Household Income      KeyUSFacts
# pci_cy          PCI_CY             2021 Per Capita Income      KeyUSFacts
# tothu_cy      TOTHU_CY           2021 Total Housing Units      KeyUSFacts
# owner_cy      OWNER_CY            2021 Owner Occupied HUs      KeyUSFacts
# renter_cy    RENTER_CY           2021 Renter Occupied HUs      KeyUSFacts
# vacant_cy    VACANT_CY          2021 Vacant Housing Units      KeyUSFacts
# medval_cy    MEDVAL_CY             2021 Median Home Value      KeyUSFacts
# avgval_cy    AVGVAL_CY            2021 Average Home Value      KeyUSFacts
# popgrw10cy  POPGRW10CY  2010-2021 Growth Rate: Population      KeyUSFacts
# hhgrw10cy    HHGRW10CY  2010-2021 Growth Rate: Households      KeyUSFacts
# famgrw10cy  FAMGRW10CY    2010-2021 Growth Rate: Families      KeyUSFacts
# dpop_cy        DPOP_CY      2021 Total Daytime Population      KeyUSFacts
# dpopwrk_cy  DPOPWRK_CY          2021 Daytime Pop: Workers      KeyUSFacts
# dpopres_cy  DPOPRES_CY        2021 Daytime Pop: Residents      KeyUSFacts
#
#                       enrich_name      enrich_field_name  \
# name
# totpop_cy    KeyUSFacts.TOTPOP_CY   KeyUSFacts_TOTPOP_CY
# gqpop_cy      KeyUSFacts.GQPOP_CY    KeyUSFacts_GQPOP_CY
# divindx_cy  KeyUSFacts.DIVINDX_CY  KeyUSFacts_DIVINDX_CY
# tothh_cy      KeyUSFacts.TOTHH_CY    KeyUSFacts_TOTHH_CY
# avghhsz_cy  KeyUSFacts.AVGHHSZ_CY  KeyUSFacts_AVGHHSZ_CY
# medhinc_cy  KeyUSFacts.MEDHINC_CY  KeyUSFacts_MEDHINC_CY
# avghinc_cy  KeyUSFacts.AVGHINC_CY  KeyUSFacts_AVGHINC_CY
# pci_cy          KeyUSFacts.PCI_CY      KeyUSFacts_PCI_CY
# tothu_cy      KeyUSFacts.TOTHU_CY    KeyUSFacts_TOTHU_CY
# owner_cy      KeyUSFacts.OWNER_CY    KeyUSFacts_OWNER_CY
# renter_cy    KeyUSFacts.RENTER_CY   KeyUSFacts_RENTER_CY
# vacant_cy    KeyUSFacts.VACANT_CY   KeyUSFacts_VACANT_CY
# medval_cy    KeyUSFacts.MEDVAL_CY   KeyUSFacts_MEDVAL_CY
# avgval_cy    KeyUSFacts.AVGVAL_CY   KeyUSFacts_AVGVAL_CY
# popgrw10cy  KeyUSFacts.POPGRW10CY  KeyUSFacts_POPGRW10CY
# hhgrw10cy    KeyUSFacts.HHGRW10CY   KeyUSFacts_HHGRW10CY
# famgrw10cy  KeyUSFacts.FAMGRW10CY  KeyUSFacts_FAMGRW10CY
# dpop_cy        KeyUSFacts.DPOP_CY     KeyUSFacts_DPOP_CY
# dpopwrk_cy  KeyUSFacts.DPOPWRK_CY  KeyUSFacts_DPOPWRK_CY
# dpopres_cy  KeyUSFacts.DPOPRES_CY  KeyUSFacts_DPOPRES_CY
#
#                                                   description vintage  \
# name
# totpop_cy                        2021 Total Population (Esri)    2021
# gqpop_cy                2021 Group Quarters Population (Esri)    2021
# divindx_cy                        2021 Diversity Index (Esri)    2021
# tothh_cy                         2021 Total Households (Esri)    2021
# avghhsz_cy                 2021 Average Household Size (Esri)    2021
# medhinc_cy                2021 Median Household Income (Esri)    2021
# avghinc_cy               2021 Average Household Income (Esri)    2021
# pci_cy                          2021 Per Capita Income (Esri)    2021
# tothu_cy                      2021 Total Housing Units (Esri)    2021
# owner_cy             2021 Owner Occupied Housing Units (Esri)    2021
# renter_cy           2021 Renter Occupied Housing Units (Esri)    2021
# vacant_cy                    2021 Vacant Housing Units (Esri)    2021
# medval_cy                       2021 Median Home Value (Esri)    2021
# avgval_cy                      2021 Average Home Value (Esri)    2021
# popgrw10cy  2010-2021 Population: Compound Annual Growth R...    2021
# hhgrw10cy   2010-2021 Households: Compound Annual Growth R...    2021
# famgrw10cy  2010-2021 Families: Compound Annual Growth Rat...    2021
# dpop_cy                  2021 Total Daytime Population (Esri)    2021
# dpopwrk_cy            2021 Daytime Population: Workers (Esri)    2021
# dpopres_cy          2021 Daytime Population: Residents (Esri)    2021
#
#                units
# name
# totpop_cy      count
# gqpop_cy       count
# divindx_cy     count
# tothh_cy       count
# avghhsz_cy     count
# medhinc_cy  currency
# avghinc_cy  currency
# pci_cy      currency
# tothu_cy       count
# owner_cy       count
# renter_cy      count
# vacant_cy      count
# medval_cy   currency
# avgval_cy   currency
# popgrw10cy       pct
# hhgrw10cy        pct
# famgrw10cy       pct
# dpop_cy        count
# dpopwrk_cy     count
# dpopres_cy     count

# %%
enrich_df = usa.enrich(mcpp_df, enrich_variables=ev_df, return_geometry=False)

enrich_df.info()
enrich_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   mcpp                               58 non-null     string
#  1   source_country                     58 non-null     object
#  2   aggregation_method                 58 non-null     object
#  3   population_to_polygon_size_rating  58 non-null     float64
#  4   apportionment_confidence           58 non-null     float64
#  5   has_data                           58 non-null     int64
#  6   totpop_cy                          58 non-null     int64
#  7   gqpop_cy                           58 non-null     int64
#  8   divindx_cy                         58 non-null     float64
#  9   tothh_cy                           58 non-null     int64
#  10  avghhsz_cy                         58 non-null     float64
#  11  medhinc_cy                         58 non-null     int64
#  12  avghinc_cy                         58 non-null     int64
#  13  pci_cy                             58 non-null     int64
#  14  tothu_cy                           58 non-null     int64
#  15  owner_cy                           58 non-null     int64
#  16  renter_cy                          58 non-null     int64
#  17  vacant_cy                          58 non-null     int64
#  18  medval_cy                          58 non-null     int64
#  19  avgval_cy                          58 non-null     int64
#  20  popgrw10_cy                        58 non-null     float64
#  21  hhgrw10_cy                         58 non-null     float64
#  22  famgrw10_cy                        58 non-null     float64
#  23  dpop_cy                            58 non-null     int64
#  24  dpopwrk_cy                         58 non-null     int64
#  25  dpopres_cy                         58 non-null     int64
# dtypes: float64(7), int64(16), object(2), string(1)
# memory usage: 11.9+ KB
#               mcpp source_country  \
# 0  ALASKA JUNCTION            USA
# 1             ALKI            USA
# 2    BALLARD NORTH            USA
# 3    BALLARD SOUTH            USA
# 4         BELLTOWN            USA
#
#                                   aggregation_method  \
# 0  BlockApportionment:US.BlockGroups;PointsLayer:...
# 1  BlockApportionment:US.BlockGroups;PointsLayer:...
# 2  BlockApportionment:US.BlockGroups;PointsLayer:...
# 3  BlockApportionment:US.BlockGroups;PointsLayer:...
# 4  BlockApportionment:US.BlockGroups;PointsLayer:...
#
#    population_to_polygon_size_rating  apportionment_confidence  has_data  \
# 0                              2.191                     2.576         1
# 1                              2.191                     2.576         1
# 2                              2.191                     2.576         1
# 3                              2.191                     2.576         1
# 4                              2.191                     2.576         1
#
#    totpop_cy  gqpop_cy  divindx_cy  tothh_cy  ...  renter_cy  vacant_cy  \
# 0      16369       290        44.3      8411  ...       4646        386
# 1       7109        15        37.3      3796  ...       1619        328
# 2      29728       253        38.1     12652  ...       3430        340
# 3      24683       226        42.0     13604  ...       8778        914
# 4      11652       458        62.2      8197  ...       6148       1100
#
#    medval_cy  avgval_cy  popgrw10_cy  hhgrw10_cy  famgrw10_cy  dpop_cy  \
# 0     714205     769011         3.03        3.38         3.24    15647
# 1     963208    1098265         0.91        0.78         0.97     5648
# 2     797390     863355         1.07        0.89         1.07    25037
# 3     787224     862277         2.59        2.70         2.67    27042
# 4     784631     906881         2.74        2.92         3.16    20200
#
#    dpopwrk_cy  dpopres_cy
# 0        9161        6486
# 1        3045        2603
# 2       13236       11801
# 3       18956        8086
# 4       16581        3619
#
# [5 rows x 26 columns]

# %%
id_col = 'mcpp'

keep_cols = [c for c in enrich_df.columns if (c == id_col) or (c in ev_df.index)]

keep_cols
# Out:
# ['mcpp',
#  'totpop_cy',
#  'gqpop_cy',
#  'divindx_cy',
#  'tothh_cy',
#  'avghhsz_cy',
#  'medhinc_cy',
#  'avghinc_cy',
#  'pci_cy',
#  'tothu_cy',
#  'owner_cy',
#  'renter_cy',
#  'vacant_cy',
#  'medval_cy',
#  'avgval_cy',
#  'dpop_cy',
#  'dpopwrk_cy',
#  'dpopres_cy']

# %%
demographics_df = enrich_df.loc[:,keep_cols].set_index(id_col, drop=True)

demographics_df.info()
demographics_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, ALASKA JUNCTION to INTERNATIONAL DISTRICT
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   totpop_cy   58 non-null     int64
#  1   gqpop_cy    58 non-null     int64
#  2   divindx_cy  58 non-null     float64
#  3   tothh_cy    58 non-null     int64
#  4   avghhsz_cy  58 non-null     float64
#  5   medhinc_cy  58 non-null     int64
#  6   avghinc_cy  58 non-null     int64
#  7   pci_cy      58 non-null     int64
#  8   tothu_cy    58 non-null     int64
#  9   owner_cy    58 non-null     int64
#  10  renter_cy   58 non-null     int64
#  11  vacant_cy   58 non-null     int64
#  12  medval_cy   58 non-null     int64
#  13  avgval_cy   58 non-null     int64
#  14  dpop_cy     58 non-null     int64
#  15  dpopwrk_cy  58 non-null     int64
#  16  dpopres_cy  58 non-null     int64
# dtypes: float64(2), int64(15)
# memory usage: 8.2 KB
#                  totpop_cy  gqpop_cy  divindx_cy  tothh_cy  avghhsz_cy  \
# mcpp
# ALASKA JUNCTION      16369       290        44.3      8411        1.91
# ALKI                  7109        15        37.3      3796        1.87
# BALLARD NORTH        29728       253        38.1     12652        2.33
# BALLARD SOUTH        24683       226        42.0     13604        1.80
# BELLTOWN             11652       458        62.2      8197        1.37
#
#                  medhinc_cy  avghinc_cy  pci_cy  tothu_cy  owner_cy  \
# mcpp
# ALASKA JUNCTION      107440      140261   72403      8797      3765
# ALKI                 153758      189606   99208      4124      2177
# BALLARD NORTH        129879      177574   75402     12992      9222
# BALLARD SOUTH        102152      146090   80706     14518      4826
# BELLTOWN             104765      148608  104679      9297      2049
#
#                  renter_cy  vacant_cy  medval_cy  avgval_cy  dpop_cy  \
# mcpp
# ALASKA JUNCTION       4646        386     714205     769011    15647
# ALKI                  1619        328     963208    1098265     5648
# BALLARD NORTH         3430        340     797390     863355    25037
# BALLARD SOUTH         8778        914     787224     862277    27042
# BELLTOWN              6148       1100     784631     906881    20200
#
#                  dpopwrk_cy  dpopres_cy
# mcpp
# ALASKA JUNCTION        9161        6486
# ALKI                   3045        2603
# BALLARD NORTH         13236       11801
# BALLARD SOUTH         18956        8086
# BELLTOWN              16581        3619

# %%
crime_demog_df = crime_mcpp_dt_df.join(demographics_df, on=id_col)

crime_demog_df.info()
crime_demog_df.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3262 entries, 0 to 3319
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   mcpp                    3262 non-null   object
#  1   offense_start_datetime  3262 non-null   datetime64[ns]
#  2   crime_count             3262 non-null   int64
#  3   totpop_cy               3147 non-null   float64
#  4   gqpop_cy                3147 non-null   float64
#  5   divindx_cy              3147 non-null   float64
#  6   tothh_cy                3147 non-null   float64
#  7   avghhsz_cy              3147 non-null   float64
#  8   medhinc_cy              3147 non-null   float64
#  9   avghinc_cy              3147 non-null   float64
#  10  pci_cy                  3147 non-null   float64
#  11  tothu_cy                3147 non-null   float64
#  12  owner_cy                3147 non-null   float64
#  13  renter_cy               3147 non-null   float64
#  14  vacant_cy               3147 non-null   float64
#  15  medval_cy               3147 non-null   float64
#  16  avgval_cy               3147 non-null   float64
#  17  dpop_cy                 3147 non-null   float64
#  18  dpopwrk_cy              3147 non-null   float64
#  19  dpopres_cy              3147 non-null   float64
# dtypes: datetime64[ns](1), float64(17), int64(1), object(1)
# memory usage: 535.2+ KB
#                 mcpp offense_start_datetime  crime_count  totpop_cy  gqpop_cy  \
# 3051  SOUTH DELRIDGE             2021-09-26            4     1650.0       0.0
# 2354   PHINNEY RIDGE             2021-05-09           10    10225.0     217.0
# 1043         FREMONT             2021-05-30           34    14107.0     169.0
# 1352   HIGHLAND PARK             2021-10-31           12    10750.0      36.0
# 1235       GREENWOOD             2021-10-10           24    18812.0      63.0
#
#       divindx_cy  tothh_cy  avghhsz_cy  medhinc_cy  avghinc_cy   pci_cy  \
# 3051        88.4     611.0        2.70     55297.0     78475.0  29551.0
# 2354        35.2    4638.0        2.16    127255.0    178113.0  80828.0
# 1043        44.4    7877.0        1.77    109873.0    154936.0  83889.0
# 1352        78.1    4132.0        2.59     67816.0     96953.0  37324.0
# 1235        58.2    8784.0        2.13    100490.0    128966.0  60361.0
#
#       tothu_cy  owner_cy  renter_cy  vacant_cy  medval_cy  avgval_cy  dpop_cy  \
# 3051     648.0     275.0      336.0       37.0   485119.0   512091.0   1361.0
# 2354    4835.0    2885.0     1754.0      197.0   858199.0   908466.0   9496.0
# 1043    8236.0    2550.0     5328.0      359.0   788215.0   826971.0  15599.0
# 1352    4855.0    2637.0     1495.0      723.0   478492.0   532108.0   8479.0
# 1235    9179.0    4522.0     4262.0      395.0   627871.0   662022.0  16417.0
#
#       dpopwrk_cy  dpopres_cy
# 3051       652.0       709.0
# 2354      5956.0      3540.0
# 1043     12094.0      3505.0
# 1352      3614.0      4865.0
# 1235      9655.0      6762.0

# %%
crime_demog_df['crime_per_capita'] = crime_demog_df['crime_count'] / crime_demog_df['totpop_cy']

crime_demog_df.crime_per_capita = crime_demog_df.crime_per_capita.replace(np.inf, 0.0)

crime_demog_df.sort_values('crime_per_capita', ascending=False)[['mcpp', 'offense_start_datetime', 'crime_count', 'totpop_cy', 'dpop_cy', 'crime_per_capita']]
# Out:
#                      mcpp offense_start_datetime  crime_count  totpop_cy  \
# 694   COMMERCIAL DUWAMISH             2021-05-16            6        2.0
# 695   COMMERCIAL DUWAMISH             2021-05-23            5        2.0
# 737   COMMERCIAL DUWAMISH             2022-05-22            4        2.0
# 725   COMMERCIAL DUWAMISH             2022-01-30            4        2.0
# 714   COMMERCIAL DUWAMISH             2021-10-31            4        2.0
# ...                   ...                    ...          ...        ...
# 1720       MADRONA/LESCHI             2022-05-01           15        NaN
# 1721       MADRONA/LESCHI             2022-05-08           12        NaN
# 1722       MADRONA/LESCHI             2022-05-15           18        NaN
# 1723       MADRONA/LESCHI             2022-05-22           16        NaN
# 1724       MADRONA/LESCHI             2022-05-29           11        NaN
#
#       dpop_cy  crime_per_capita
# 694    1060.0               3.0
# 695    1060.0               2.5
# 737    1060.0               2.0
# 725    1060.0               2.0
# 714    1060.0               2.0
# ...       ...               ...
# 1720      NaN               NaN
# 1721      NaN               NaN
# 1722      NaN               NaN
# 1723      NaN               NaN
# 1724      NaN               NaN
#
# [3262 rows x 6 columns]

# %%
crime_demog_df['crime_per_capita'] = crime_demog_df['crime_count'] / crime_demog_df['dpop_cy']

crime_demog_df.crime_per_capita = crime_demog_df.crime_per_capita.replace(np.inf, 0.0)

crime_demog_df.sort_values('crime_per_capita', ascending=False)[['mcpp', 'offense_start_datetime', 'crime_count', 'totpop_cy', 'dpop_cy', 'crime_per_capita']]
# Out:
#                  mcpp offense_start_datetime  crime_count  totpop_cy  dpop_cy  \
# 3078   SOUTH DELRIDGE             2022-04-03           16     1650.0   1361.0
# 3069   SOUTH DELRIDGE             2022-01-30           14     1650.0   1361.0
# 821   EASTLAKE - EAST             2021-05-16            9     1109.0    946.0
# 1151          GENESEE             2022-05-22           14     1656.0   1552.0
# 826   EASTLAKE - EAST             2021-07-04            8     1109.0    946.0
# ...               ...                    ...          ...        ...      ...
# 1720   MADRONA/LESCHI             2022-05-01           15        NaN      NaN
# 1721   MADRONA/LESCHI             2022-05-08           12        NaN      NaN
# 1722   MADRONA/LESCHI             2022-05-15           18        NaN      NaN
# 1723   MADRONA/LESCHI             2022-05-22           16        NaN      NaN
# 1724   MADRONA/LESCHI             2022-05-29           11        NaN      NaN
#
#       crime_per_capita
# 3078          0.011756
# 3069          0.010287
# 821           0.009514
# 1151          0.009021
# 826           0.008457
# ...                ...
# 1720               NaN
# 1721               NaN
# 1722               NaN
# 1723               NaN
# 1724               NaN
#
# [3262 rows x 6 columns]

# %%
def get_slope_coef(unique_value:str, y_col:str='crime_per_capita', df:pd.DataFrame=crime_demog_df, dt_col:str='offense_start_datetime', id_col:str='mcpp')->Tuple:
    
    # ensure input columns are available
    assert unique_value in df[id_col].values
    assert y_col in df.columns
    assert dt_col in df.columns
    assert id_col in df.columns

    # filter to just the data for the input mcpp
    mcpp_subset_df = df[df.mcpp == unique_value]

    # extract and format the X and y inputs for modeling
    X = mcpp_subset_df[dt_col].astype(int).values.reshape(-1, 1)
    y = mcpp_subset_df[y_col].values

    # use linear regression from SciKit Learn to get the slope coefficient
    lm = LinearRegression()
    lm.fit(X, y)
    slope_coef = lm.coef_[0]

    return (unique_value, slope_coef)


get_slope_coef('ALASKA JUNCTION')
# Out:
# ('ALASKA JUNCTION', 1.3249140323247507e-20)

# %%
coef_df = pd.DataFrame([get_slope_coef(mcpp) for mcpp in crime_mcpp_dt_df.mcpp.unique()], columns=['mcpp', 'slope_coef'])

coef_df.info()
coef_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [97], in <cell line: 1>()
# ----> 1 coef_df = pd.DataFrame([get_slope_coef(mcpp) for mcpp in crime_mcpp_dt_df.mcpp.unique()], columns=['mcpp', 'slope_coef'])
#       3 coef_df.info()
#       4 coef_df.head()
#
# Input In [97], in <listcomp>(.0)
# ----> 1 coef_df = pd.DataFrame([get_slope_coef(mcpp) for mcpp in crime_mcpp_dt_df.mcpp.unique()], columns=['mcpp', 'slope_coef'])
#       3 coef_df.info()
#       4 coef_df.head()
#
# Input In [96], in get_slope_coef(unique_value, y_col, df, dt_col, id_col)
#      16 # use linear regression from SciKit Learn to get the slope coefficient
#      17 lm = LinearRegression()
# ---> 18 lm.fit(X, y)
#      19 slope_coef = lm.coef_[0]
#      21 return (unique_value, slope_coef)
#
# File ~/projects/business-analyst-python-api-examples/env/lib/python3.9/site-packages/sklearn/linear_model/_base.py:684, in LinearRegression.fit(self, X, y, sample_weight)
#     680 n_jobs_ = self.n_jobs
#     682 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 684 X, y = self._validate_data(
#     685     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     686 )
#     688 sample_weight = _check_sample_weight(
#     689     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     690 )
#     692 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     693     X,
#     694     y,
#    (...)
#     698     sample_weight=sample_weight,
#     699 )
#
# File ~/projects/business-analyst-python-api-examples/env/lib/python3.9/site-packages/sklearn/base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/projects/business-analyst-python-api-examples/env/lib/python3.9/site-packages/sklearn/utils/validation.py:1090, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
#    1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    (...)
#    1087     input_name="X",
#    1088 )
# -> 1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#    1094 return X, y
#
# File ~/projects/business-analyst-python-api-examples/env/lib/python3.9/site-packages/sklearn/utils/validation.py:1100, in _check_y(y, multi_output, y_numeric, estimator)
#    1098 """Isolated part of check_X_y dedicated to y validation"""
#    1099 if multi_output:
# -> 1100     y = check_array(
#    1101         y,
#    1102         accept_sparse="csr",
#    1103         force_all_finite=True,
#    1104         ensure_2d=False,
#    1105         dtype=None,
#    1106         input_name="y",
#    1107         estimator=estimator,
#    1108     )
#    1109 else:
#    1110     estimator_name = _check_estimator_name(estimator)
#
# File ~/projects/business-analyst-python-api-examples/env/lib/python3.9/site-packages/sklearn/utils/validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File ~/projects/business-analyst-python-api-examples/env/lib/python3.9/site-packages/sklearn/utils/validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input y contains NaN.
